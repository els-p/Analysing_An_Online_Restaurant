# %% [markdown]
# # Unsupervised Clustering using PCA and K Means

# %%
#Import libraries
import pandas as pd
import seaborn as sns
import numpy as np
import string

from tqdm import tqdm_notebook as tqdm
from keras.utils import np_utils
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
# Out:
# Using TensorFlow backend.

# %%
#Import data
df = pd.read_csv('../inputs/profile_features_clean.csv')

# %%
#Inspect data
pd.options.display.max_columns = None
df.sample(3)
# Out:
#                   address  postal_code  account_balance  card_brand_users  \
# 15357     111 Middle Road     188969.0                0  American Express
# 21621   21 Teck Whye Walk     688258.0                0        MasterCard
# 54025  8 Marina Boulevard      18981.0             1420              Visa
#
#        has_coupon  birthday_year  birthday_month  age  region  user_id  \
# 15357           0            NaN             NaN  NaN     7.0    35331
# 21621           0            NaN             NaN  NaN    23.0    38689
# 54025           0            NaN             NaN  NaN     1.0    10027
#
#        zone_id  discount due_dates_only  \
# 15357     74.0       0.0     2017-06-14
# 21621     61.0       0.0     2017-10-04
# 54025     74.0       0.0     2016-09-14
#
#                                             card_details  \
# 15357                                                NaN
# 21621                                                NaN
# 54025  ---\n14/9:\n  :name: '14/9 | 12:00pm | MBFC1 |...
#
#       card_brand_delivery_info source  delivery_fee meal_wave  \
# 15357         American Express    web         200.0     third
# 21621               MasterCard    web         500.0     first
# 54025                     Visa      0           0.0    second
#
#        surcharge_amount  promo_code_used  gave_feedback  delivery_order_id  \
# 15357               0.0                0              1              92612
# 21621               0.0                0              0             102202
# 54025               0.0                0              0              65436
#
#        item_id item_type  quantity  unit_price  \
# 15357    361.0      main       1.0      1595.0
# 21621    484.0      main       8.0      1450.0
# 54025    338.0   dessert       1.0       495.0
#
#                                  name  \
# 15357  Black Garlic Glazed Beef Cheek
# 21621             Slow Cooked Salmon
# 54025               Gateau a l'Orange
#
#                                                  macros  \
# 15357  Calories: 610, Fat: 22g, Carb: 53g, Protein: 47g
# 21621  Calories: 771, Fat: 26g, Carb: 85g, Protein: 45g
# 54025   Calories: 331, Fat: 20g, Carb: 32g, Protein: 7g
#
#                                              ingredients temperature  \
# 15357  beef cheek, beef stock, chicken stock, potato,...        warm
# 21621  salmon, risoni pasta, spinach, shimeji mushroo...        warm
# 54025  butter, sugar, eggs, flour, baking powder, dic...     chilled
#
#         category
# 15357  highlight
# 21621  highlight
# 54025    dessert

# %%
ini_rows = df.shape[0]
ini_columns=df.shape[1]
print('We have {} records of transactions from {} unique users.'.format(ini_rows,df.user_id.nunique()))
# Out:
# We have 57283 records of transactions from 8886 unique users.

# %%
#Find pct of missing values in each column
missing_pct = pd.DataFrame(df.isnull().sum()/df.shape[0], columns=['%Null']).sort_values('%Null',ascending=False)

#Print only those with missing values
missing_pct[missing_pct['%Null']> 0]
# Out:
#                              %Null
# birthday_year             0.877520
# age                       0.877520
# birthday_month            0.875024
# card_details              0.616483
# card_brand_delivery_info  0.322033
# card_brand_users          0.114379
# category                  0.001554
# ingredients               0.001082
# address                   0.000035
# region                    0.000035
# item_type                 0.000017

# %% [markdown]
# ## Computing Missing values

# %% [markdown]
# ### Item_type

# %%
#Inspect item name in row with missing value
df[df.item_type.isnull()].name
# Out:
# 16678    Pink Coconut Water
# Name: name, dtype: object

# %%
#Check possible values
df.item_type.unique()
# Out:
# array(['main', 'drink', nan, 'side', 'dessert', 'product', 'BundleItem'],
#       dtype=object)

# %%
#Compute as drink
df.item_type.fillna('drink', inplace=True)

# %% [markdown]
# ### Region

# %%
#Inspect postal code in row with missing value
df[df.region.isnull()].postal_code
# Out:
# 32747    0.0
# 44036    0.0
# Name: postal_code, dtype: float64

# %% [markdown]
# We will drop the rows, given no information.

# %%
#Drop rows
df = df[df.region.notnull()]

# %%
print('We dropped {} rows.'.format(ini_rows-df.shape[0]))
# Out:
# We dropped 2 rows.

# %% [markdown]
# ### Ingredients

# %%
#Inspect unique item names for rows with missing values
df[df.ingredients.isnull()]['name'].value_counts()
# Out:
# Teriyaki Chicken with Japanese Risotto             28
# Smoked Salmon Salad with Compressed Cider Apple    23
# Vietnamese Salad                                    6
# Personalised meal                                   4
# Beef Goulash with Polenta Cake                      1
# Name: name, dtype: int64

# %%
#Compile ingredients as corpus
texts = pd.DataFrame(df[df.ingredients.notnull()].ingredients)

# %%
#Inspect corpus
texts.head()
# Out:
#                                          ingredients
# 0  salmon, couscous, eggplant, zucchini, onion, c...
# 1  salmon, couscous, eggplant, zucchini, onion, c...
# 2  salmon, couscous, eggplant, zucchini, onion, c...
# 3  salmon, couscous, eggplant, zucchini, onion, c...
# 4  salmon, couscous, eggplant, zucchini, onion, c...

# %%
#Remove convert to lowercase and remove punctuations
texts['clean_text'] = texts.ingredients.map(lambda x : ''.join(k.lower() for k in str(x) if k not in string.punctuation))

# %%
#Vectorise the corpus
cvec = CountVectorizer(stop_words='english')
cvec.fit(texts.clean_text)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
print('# of features: {}'.format(len(cvec.get_feature_names())))
# Out:
# # of features: 695

# %%
#Find most common ingredients
bow = pd.DataFrame(cvec.transform(texts.clean_text).todense(),columns=cvec.get_feature_names())
word_count = bow.sum(axis=0)

print("Most common ingredients:")
word_count.sort_values(ascending = False).head(20)
# Out:
# Most common ingredients:
# oil         49242
# rice        43820
# salt        38561
# juice       32020
# sauce       29574
# chicken     27073
# olive       26868
# sugar       26863
# black       26674
# tomato      26519
# garlic      24513
# white       24214
# onion       24154
# brown       23566
# lime        20069
# vinegar     19942
# cherry      18845
# chilli      18080
# sesame      17038
# mushroom    16293
# dtype: int64

# %% [markdown]
# We will not use this column for modelling as yet.

# %% [markdown]
# ### Category

# %%
#Inspect unique item types of rows with missing value
df[df.category.isnull()]['item_type'].value_counts()
# Out:
# main    89
# Name: item_type, dtype: int64

# %%
#Inspect unique item names of rows with missing value
df[df.category.isnull()]['name'].value_counts()
# Out:
# Chirashi-don    89
# Name: name, dtype: int64

# %% [markdown]
# We are missing category for the main, Chirashi-don.

# %%
#Check possible values
df.category.value_counts()
# Out:
# regular        25669
# highlight       9022
# main            5862
# drink           5128
# side            3998
# favorite        2075
# dessert         2060
# off_menu        1082
# guilt-free      1011
# local            904
# fresh            345
# Main Course       22
# Appetiser          5
# Dessert            5
# partnership        4
# Name: category, dtype: int64

# %%
#Fill missing values as 'main'
df.category.fillna('main', inplace=True)

# %% [markdown]
# There are repeated categories such as 'main' and 'Main Course' which can be consolidated.

# %%
#Consolidating similiar categories
def consolidate_cat(x):
    if x == 'Main Course':
        return 'main'
    elif x == 'Appetiser':
        return 'side'
    elif x == 'Dessert':
        return 'dessert'
    elif x == 'partnership':
        return 'off_menu'
    else:
        return x

df.category = df.category.apply(lambda x : consolidate_cat(x))

#Print new categories
df.category.value_counts()
# Out:
# regular       25669
# highlight      9022
# main           5973
# drink          5128
# side           4003
# favorite       2075
# dessert        2065
# off_menu       1086
# guilt-free     1011
# local           904
# fresh           345
# Name: category, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Macros

# %% [markdown]
# Split out macros into components: Calories, Fat, Protein, Carbs

# %%
#Inspect macros
df.macros.head()
# Out:
# 0    Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 1    Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 2    Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 3    Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 4    Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# Name: macros, dtype: object

# %%
new = df.macros.str.split(',', n=5, expand=True)

# %%
def split_values_into_name_and_val(col):
    new[str(col)+'_macros_name'] = new[col].str.split(': ', n=2, expand=True)[0].fillna('None').map(lambda x: x.lower())
    new[str(col)+'_macros_val'] = new[col].str.split(': ', n=2, expand=True)[1]
    print(new[str(col)+'_macros_name'].unique())

for col in new:
    split_values_into_name_and_val(col)

new.head()
# Out:
# ['calories' 'serving size' 'coming soon' '0'
#  'information included in christmas box' ' calories']
# [' fat' ' protein' ' calories' 'none' ' carbs']
# [' carb' ' fat' 'none' ' protein']
# [' protein' ' carb' 'none' '  fat']
# ['none' ' protein']
#                0          1           2              3     4 0_macros_name  \
# 0  Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 1  Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 2  Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 3  Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 4  Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
#
#   0_macros_val 1_macros_name 1_macros_val 2_macros_name 2_macros_val  \
# 0          442           fat          12g          carb          42g
# 1          442           fat          12g          carb          42g
# 2          442           fat          12g          carb          42g
# 3          442           fat          12g          carb          42g
# 4          442           fat          12g          carb          42g
#
#   3_macros_name 3_macros_val 4_macros_name 4_macros_val
# 0       protein          44g          none         None
# 1       protein          44g          none         None
# 2       protein          44g          none         None
# 3       protein          44g          none         None
# 4       protein          44g          none         None

# %%
new.shape
# Out:
# (57281, 15)

# %%
new['calories'] = 0
new['fat'] = 0
new['protein'] = 0
new['carb'] = 0

# %%
new.loc[new['0_macros_name'] == 'calories', 'calories'] = new.loc[new['0_macros_name'] == 'calories', '0_macros_val']
new.loc[new['0_macros_name'] == ' calories', 'calories'] = new.loc[new['0_macros_name'] == ' calories', '0_macros_val']

new.loc[new['1_macros_name'] == ' calories', 'calories'] = new.loc[new['1_macros_name'] == ' calories', '1_macros_val']
new.loc[new['1_macros_name'] == ' fat', 'fat'] = new.loc[new['1_macros_name'] == ' fat', '1_macros_val']
new.loc[new['1_macros_name'] == ' protein', 'protein'] = new.loc[new['1_macros_name'] == ' protein', '1_macros_val']
new.loc[new['1_macros_name'] == ' carbs', 'carb'] = new.loc[new['1_macros_name'] == ' carbs', '1_macros_val']

new.loc[new['2_macros_name'] == ' fat', 'fat'] = new.loc[new['2_macros_name'] == ' fat', '2_macros_val']
new.loc[new['2_macros_name'] == ' protein', 'protein'] = new.loc[new['2_macros_name'] == ' protein', '2_macros_val']
new.loc[new['2_macros_name'] == ' carb', 'carb'] = new.loc[new['2_macros_name'] == ' carb', '2_macros_val']

new.loc[new['3_macros_name'] == ' fat', 'fat'] = new.loc[new['3_macros_name'] == ' fat', '3_macros_val']
new.loc[new['3_macros_name'] == ' protein', 'protein'] = new.loc[new['3_macros_name'] == ' protein', '3_macros_val']
new.loc[new['3_macros_name'] == ' carb', 'carb'] = new.loc[new['3_macros_name'] == ' carb', '3_macros_val']

new.loc[new['4_macros_name'] == ' protein', 'protein'] = new.loc[new['4_macros_name'] == ' protein', '4_macros_val']

# %%
#Remove g
cols = ['fat','protein','carb']
for i in cols:
    new[str(i)] = new[str(i)].apply(lambda x: str(x).split('g')[0])

# %%
df = pd.concat([df, new[['calories','fat','protein','carb']]],axis=1)

for i in ['calories', 'fat','protein','carb']:
    df[i] = df[i].astype(float)

# %% [markdown]
# ### Account Balance

# %%
df.account_balance.dtype
# Out:
# dtype('int64')

# %%
df['use_wallet'] = df.account_balance.map(lambda x: 1 if x != 0 else 0)

# %%
df.use_wallet.value_counts()
# Out:
# 0    45912
# 1    11369
# Name: use_wallet, dtype: int64

# %% [markdown]
# ### Meal wave

# %%
df.meal_wave.value_counts()
# Out:
# first     28262
# second    20047
# third      7285
# 0          1687
# Name: meal_wave, dtype: int64

# %%
df_mw = pd.get_dummies(df.meal_wave, drop_first=True)

# %% [markdown]
# ### Calorie, Fat, Protein, Carb preference

# %%
cal = df.groupby('item_id')['calories'].mean()
plt.figure(figsize=(15,5))
sns.distplot(cal, bins=40)
plt.xticks(np.arange(min(cal), max(cal)+1, 50))
plt.show()

# %%
#Low calorie == ≤100g (≤ 40 kilocalorie per 100g for 1 serving 250g)
def calorie_pref(x):
    if x <= 100 :
        return 1 #preference for low calorie
    else:
        return 0 

df['calorie_pref'] = df.calories.map(lambda x : calorie_pref(x))

# %%
fat = df.groupby('item_id')['fat'].mean()
plt.figure(figsize=(15,5))
sns.distplot(fat, bins=40)
plt.xticks(np.arange(min(fat), max(fat)+1, 5))
plt.show()

# %%
#Low fat == ≤7.5g (≤3g fat per 100g for 1 serving 250g) 
def fat_pref(x):
    if x <= 7.5 :
        return 1 #preference for low fat
    else:
        return 0  
    
df['fat_pref'] = df.fat.map(lambda x : fat_pref(x))

# %%
pro = df.groupby('item_id')['protein'].mean()
plt.figure(figsize=(15,5))
sns.distplot(pro, bins=40)
plt.xticks(np.arange(min(pro), max(pro)+1, 5))
plt.show()

# %%
#Rich in protein == ≥25 (≥10g of protein per 100g for 1 serving 250g)
def pro_pref(x):
    if x >= 25 :
        return 1 #preference for high protein
    else:
        return 0  
    
df['pro_pref'] = df.protein.map(lambda x : pro_pref(x))

# %%
carbs = df.groupby('item_id')['carb'].mean()
plt.figure(figsize=(15,5))
sns.distplot(carbs, bins=40)
plt.xticks(np.arange(min(carbs), max(carbs)+1, 5))
plt.show()

# %%
#Low carbs == ≤25 (≤10 g carbohydrate per 100g for 1 serving 250g)
def carb_pref(x):
    if x <= 25 :
        return 1 #preference for low carb
    else:
        return 0  
    
df['carb_pref'] = df.carb.map(lambda x : carb_pref(x))

# %%
df[['calorie_pref','pro_pref','fat_pref','carb_pref']].isnull().sum()
# Out:
# calorie_pref    0
# pro_pref        0
# fat_pref        0
# carb_pref       0
# dtype: int64

# %%
df.groupby('user_id').sum()['quantity'].sort_values(ascending=False).head()
# Out:
# user_id
# 20373    26782.0
# 28133    18269.0
# 28126    17935.0
# 4727      6220.0
# 5691      2520.0
# Name: quantity, dtype: float64

# %% [markdown]
# Find preferences of the user for which we have the most data points. We will normalise this later.

# %%
norm = pd.DataFrame(df[df.user_id == 20373][['calorie_pref', 'fat_pref','pro_pref', 'carb_pref']].mean())
norm
# Out:
#                      0
# calorie_pref  0.921053
# fat_pref      0.921053
# pro_pref      0.052632
# carb_pref     0.921053

# %% [markdown]
# ### Group buyer

# %%
plt.figure(figsize=(15,5))
df.groupby('user_id').mean()['quantity'].hist()
plt.show()

# %%
unique_user = df.user_id.unique().tolist()

# %%
#Create new feature where average quantity > 1.5 is a user who makes group purchase
df['groupbuyer'] = 0
for user in tqdm(unique_user):
    if df.groupby('user_id')['quantity'].mean().loc[user] <= 1.5:
        df.loc[df.user_id == user, 'groupbuyer'] = 0
    else:
        df.loc[df.user_id == user, 'groupbuyer'] = 1
# Out:
# HBox(children=(IntProgress(value=0, max=8885), HTML(value='')))

# %%
df.groupbuyer.value_counts()
# Out:
# 0    39697
# 1    17584
# Name: groupbuyer, dtype: int64

# %% [markdown]
# ### Temperature

# %%
df.temperature.value_counts()
# Out:
# warm       36020
# chilled    20729
# room         532
# Name: temperature, dtype: int64

# %%
df['is_chilled'] = df.temperature.map(lambda x : 1 if x == 'chilled' else 0)

# %% [markdown]
# ### Category

# %%
df.category.value_counts()
# Out:
# regular       25669
# highlight      9022
# main           5973
# drink          5128
# side           4003
# favorite       2075
# dessert        2065
# off_menu       1086
# guilt-free     1011
# local           904
# fresh           345
# Name: category, dtype: int64

# %%
df_cat = pd.get_dummies(df.category, drop_first=True) #drop dessert
df_cat.columns
# Out:
# Index(['drink', 'favorite', 'fresh', 'guilt-free', 'highlight', 'local',
#        'main', 'off_menu', 'regular', 'side'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df_cat.corr(), annot=True, cmap='RdBu_r')
plt.show()

# %% [markdown]
# ## Modelling

# %%
df_merge_mean = pd.concat([df,df_cat,df_mw], axis=1).groupby('user_id').mean()

# %%
df_merge_mean.sample(5)
# Out:
#          postal_code  account_balance  has_coupon  birthday_year  \
# user_id
# 47570       388371.0              0.0         1.0            NaN
# 32270        79317.0              0.0         1.0            NaN
# 35069       510416.0              0.0         0.0            NaN
# 37706        18961.0              0.0         0.0            NaN
# 46159       229899.0            700.0         0.0            NaN
#
#          birthday_month  age  region  zone_id    discount  delivery_fee  \
# user_id
# 47570               NaN  NaN    14.0     74.0    0.000000         200.0
# 32270               NaN  NaN     2.0     61.0  250.000000         200.0
# 35069               NaN  NaN    18.0     74.0    0.000000         200.0
# 37706               NaN  NaN     1.0     74.0    0.000000           0.0
# 46159               NaN  NaN     9.0     74.0  285.714286         200.0
#
#          surcharge_amount  promo_code_used  gave_feedback  delivery_order_id  \
# user_id
# 47570                 0.0         0.000000       0.000000      132393.000000
# 32270                 0.0         0.500000       1.000000       89168.000000
# 35069                 0.0         0.000000       0.333333       95270.000000
# 37706                 0.0         0.000000       0.000000       98970.000000
# 46159                 0.0         0.571429       0.000000      122701.428571
#
#             item_id  quantity   unit_price    calories        fat    protein  \
# user_id
# 47570    336.000000  1.000000  1195.000000  549.000000  14.000000  45.000000
# 32270    398.500000  1.500000  1132.500000  563.000000  15.500000  51.500000
# 35069    435.777778  1.000000  1099.444444  481.966667  15.566667  31.911111
# 37706    384.500000  1.833333  1292.500000  583.666667  14.250000  40.950000
# 46159    493.428571  0.857143  1039.285714  579.571429  18.000000  30.714286
#
#               carb  use_wallet  calorie_pref  fat_pref  pro_pref  carb_pref  \
# user_id
# 47570    61.000000         0.0      0.000000  0.000000  1.000000   0.000000
# 32270    62.500000         0.0      0.000000  0.000000  1.000000   0.000000
# 35069    59.055556         0.0      0.111111  0.111111  0.555556   0.111111
# 37706    75.833333         0.0      0.000000  0.000000  0.833333   0.000000
# 46159    76.428571         1.0      0.000000  0.000000  0.714286   0.000000
#
#          groupbuyer  is_chilled     drink  favorite  fresh  guilt-free  \
# user_id
# 47570           0.0    0.000000  0.000000       0.0    0.0         0.0
# 32270           0.0    0.000000  0.000000       0.0    0.0         0.0
# 35069           0.0    0.555556  0.111111       0.0    0.0         0.0
# 37706           1.0    0.333333  0.000000       0.0    0.0         0.0
# 46159           0.0    0.285714  0.000000       0.0    0.0         0.0
#
#          highlight  local  main  off_menu   regular  side     first    second  \
# user_id
# 47570     0.000000    0.0   0.0       0.0  1.000000   0.0  1.000000  0.000000
# 32270     0.000000    0.0   0.0       0.0  1.000000   0.0  0.000000  0.000000
# 35069     0.111111    0.0   0.0       0.0  0.555556   0.0  0.666667  0.333333
# 37706     0.000000    0.0   0.0       0.0  1.000000   0.0  1.000000  0.000000
# 46159     0.000000    0.0   0.0       0.0  1.000000   0.0  1.000000  0.000000
#
#          third
# user_id
# 47570      0.0
# 32270      1.0
# 35069      0.0
# 37706      0.0
# 46159      0.0

# %%
df_merge_mean['calorie_pref_norm'] = df_merge_mean.calorie_pref/norm[0][0]
df_merge_mean['fat_pref_norm'] = df_merge_mean.fat_pref/norm[0][1]
df_merge_mean['pro_pref_norm'] = df_merge_mean.pro_pref/norm[0][2]
df_merge_mean['carb_pref_norm'] = df_merge_mean.carb_pref/norm[0][3]
df_merge_mean['is_chilled_norm'] = df_merge_mean.is_chilled/df[df.user_id == 20373][['is_chilled']].mean()[0]

# %%
df_merge_mean.columns
# Out:
# Index(['postal_code', 'account_balance', 'has_coupon', 'birthday_year',
#        'birthday_month', 'age', 'region', 'zone_id', 'discount',
#        'delivery_fee', 'surcharge_amount', 'promo_code_used', 'gave_feedback',
#        'delivery_order_id', 'item_id', 'quantity', 'unit_price', 'calories',
#        'fat', 'protein', 'carb', 'use_wallet', 'calorie_pref', 'fat_pref',
#        'pro_pref', 'carb_pref', 'groupbuyer', 'is_chilled', 'drink',
#        'favorite', 'fresh', 'guilt-free', 'highlight', 'local', 'main',
#        'off_menu', 'regular', 'side', 'first', 'second', 'third',
#        'calorie_pref_norm', 'fat_pref_norm', 'pro_pref_norm', 'carb_pref_norm',
#        'is_chilled_norm'],
#       dtype='object')

# %%
features = ['region','use_wallet','has_coupon',
            'first', 'second','third','delivery_fee',
            'gave_feedback','groupbuyer','unit_price', 'drink',
            'favorite', 'fresh', 'guilt-free', 'highlight', 
            'local', 'main','off_menu', 'regular', 
            'side','calorie_pref_norm', 'fat_pref_norm','pro_pref_norm', 
            'carb_pref_norm','is_chilled_norm'
           ]

# %%
X = df_merge_mean[features].round(2)

# %%
X.sample(5)
# Out:
#          region  use_wallet  has_coupon  first  second  third  delivery_fee  \
# user_id
# 39884      23.0         0.0         0.0   1.00    0.00    0.0         500.0
# 6582        1.0         0.0         1.0   0.00    1.00    0.0           0.0
# 34662      16.0         0.0         0.0   0.00    1.00    0.0         200.0
# 29699      19.0         0.0         0.0   0.56    0.44    0.0          62.5
# 6997        7.0         0.0         0.0   0.50    0.50    0.0         100.0
#
#          gave_feedback  groupbuyer  unit_price  drink  favorite  fresh  \
# user_id
# 39884             0.00         0.0     1322.50    0.0       0.0    0.0
# 6582              0.00         0.0     1195.00    0.0       0.0    0.0
# 34662             0.43         0.0     1077.86    0.0       0.0    0.0
# 29699             1.00         1.0     1105.31    0.0       0.0    0.0
# 6997              0.50         1.0     1127.50    0.0       0.0    0.0
#
#          guilt-free  highlight  local  main  off_menu  regular  side  \
# user_id
# 39884          0.00       0.00    0.0  0.00       0.0     1.00  0.00
# 6582           1.00       0.00    0.0  0.00       0.0     0.00  0.00
# 34662          0.00       0.00    0.0  0.00       0.0     1.00  0.00
# 29699          0.00       0.06    0.0  0.00       0.0     0.69  0.12
# 6997           0.25       0.00    0.0  0.25       0.0     0.50  0.00
#
#          calorie_pref_norm  fat_pref_norm  pro_pref_norm  carb_pref_norm  \
# user_id
# 39884                  0.0           0.00          19.00            0.00
# 6582                   0.0           0.00          19.00            0.00
# 34662                  0.0           0.16          19.00            0.00
# 29699                  0.0           0.27           9.50            0.07
# 6997                   0.0           0.00          14.25            0.00
#
#          is_chilled_norm
# user_id
# 39884              19.00
# 6582               38.00
# 34662               5.43
# 29699              16.62
# 6997               19.00

# %%
plt.figure(figsize=(15,7))
sns.heatmap(X.corr(), annot=True, cmap='RdBu_r')
plt.show()

# %%
ss = StandardScaler()
Xs = ss.fit_transform(X)

# %% [markdown]
# ### PCA

# %%
pca = PCA()
principalComponents = pca.fit_transform(Xs)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_)
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)

# Save components to a DataFrame
PCA_components = pd.DataFrame(principalComponents)

# %% [markdown]
# ### KMeans

# %%
ks = range(1, 10)
inertias = []
silhouette_scores = []
for k in ks:
    # Create a KMeans instance with k clusters: model
    knn_model = KMeans(n_clusters=k)
    
    # Fit model to samples
    knn_model.fit(PCA_components.iloc[:,:4])
    
    # Append the inertia to the list of inertias
    inertias.append(knn_model.inertia_)

    
plt.plot(ks, inertias, '-o', color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
model = KMeans(n_clusters=2)
model.fit(PCA_components.iloc[:,:4])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
pred = model.labels_

# %%
# Users and clusters
# pd.DataFrame({'Users': X.index, 'Cluster': pred})

# %%
X['cluster'] = pred

# %%
X.cluster.value_counts()
# Out:
# 0    8584
# 1     301
# Name: cluster, dtype: int64

# %%
silhouette_score(Xs, pred, metric='euclidean')
# Out:
# 0.5131202358739666
