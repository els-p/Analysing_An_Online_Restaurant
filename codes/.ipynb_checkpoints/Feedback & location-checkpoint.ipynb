# %%
import pandas as pd

# %%
fb = pd.read_csv('../raw/feedbacks.csv')

# %%
users = pd.read_csv('../raw/users.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fb.sample(5)
# Out:
#           id  rating  ratable_id   ratable_type comment  \
# 32915  58144    -1.0      194786      OrderItem     NaN
# 14029  47237     1.0      165178      OrderItem     NaN
# 31409  65436     1.0      213387      OrderItem     NaN
# 44567  78013     1.0      143016  DeliveryOrder     NaN
# 16205  48604     1.0      168352      OrderItem     NaN
#
#                        created_at                  updated_at  field_id  \
# 32915  2018-04-10 15:14:32.204731  2018-04-10 15:14:32.204731       NaN
# 14029  2017-11-03 11:45:30.650641  2017-11-03 11:45:30.650641       NaN
# 31409  2018-06-21 19:00:16.735951  2018-06-21 19:00:16.735951       NaN
# 44567  2018-09-27 08:51:01.792685  2018-09-27 08:51:01.792685       NaN
# 16205  2017-11-27 11:32:29.629773  2017-11-27 11:32:29.629773       NaN
#
#        order_id  user_id            tags
# 32915  GO294186  44647.0  ---\n- Taste\n
# 14029  GO248893  39092.0             NaN
# 31409  GO324275  45211.0             NaN
# ...

# %%
fb[(fb['user_id'].isin(users.id))].user_id.nunique()
# Out:
# 5247

# %%
loc = pd.read_csv('../raw/locations.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,10,11,12,15,26,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loc.sample(5)
# Out:
#             id postal_code                 address   longitude  latitude  \
# 140894  145882      309566       37A Chancery Lane  103.838271  1.322400
# 18882    41740      788366  61 Springleaf Crescent  103.823890  1.400120
# 50168   100772      439345       57K Crescent Road  103.890563  1.306557
# 114624   46382      769513         31 Jalan Salang  103.826327  1.438351
# 23115    49728      806446        40 Sunrise Place  103.856033  1.386589
#
#                         created_at                  updated_at  zone_id  \
# 140894  2014-07-04 11:19:25.134070  2017-03-15 12:08:55.568701      NaN
# 18882   2014-07-04 11:08:01.495603  2017-03-15 10:15:02.080461      NaN
# 50168   2014-07-04 11:14:30.540727  2017-03-15 11:18:27.180417      NaN
# 114624  2014-07-04 11:08:32.337412  2017-03-15 10:20:04.243776      NaN
# 23115   2014-07-04 11:08:53.425615  2017-03-15 10:23:25.216287      NaN
#
#         location_id  overwrite  ... delivery_fee block_slot_1 block_slot_2  \
# ...

# %%
loc.shape
# Out:
# (151940, 37)

# %%
delv = pd.read_csv('../raw/delivery_orders.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (9,13,22,31,33,35,36,38,44,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
delv
# Out:
#            id  zone_id                                            address  \
# 0       34370     74.0                                10 Marina Boulevard
# 1       34371     74.0                                10 Marina Boulevard
# 2       34372     74.0                                      8 Marina View
# 3       34373     74.0                                             ASIASQ
# 4       87519     74.0                                  138 Market Street
# 5        4271     74.0      NTUC Centre (One Marina Boulevard) taxi stand
# 6       64676     61.0                                 528 Miltonia Close
# 7       34381     74.0                                12 Marina Boulevard
# 8       34374     74.0                                              MBFC2
# 9       34375     74.0                                10 Marina Boulevard
# 10      34376     74.0                                             ASIASQ
# 11      34377     74.0                                                ORQ
# ...

# %%
# delv.isnull().sum().sort_values()

# %%
# loc[(loc['id'].isin(delv.location_id))].shape
# Out:
# (3240, 37)

# %%
delv[(delv['location_id'].isin(loc.id))].shape
# Out:
# (32900, 71)

# %%
delv.merge(loc, left_on='location_id', right_on='id', suffixes=('_delivery','_loc')).shape
# Out:
# (32900, 108)
