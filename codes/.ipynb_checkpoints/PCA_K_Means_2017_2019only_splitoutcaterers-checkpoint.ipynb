# %% [markdown]
# # Unsupervised Clustering using PCA and K Means

# %%
#Import libraries
import pandas as pd
import seaborn as sns
import numpy as np
import string

from tqdm import tqdm_notebook as tqdm
from keras.utils import np_utils
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
# Out:
# Using TensorFlow backend.

# %%
#Import data
df = pd.read_csv('../inputs/profile_features_clean.csv')

# %%
#Inspect data
pd.options.display.max_columns = None
df.sample(3)
# Out:
#                           address  postal_code  account_balance  \
# 18099             3 Fraser Street     189352.0                0
# 53242               8 Farrer Road     268820.0                0
# 39352  271 Choa Chu Kang Avenue 2     680271.0                0
#
#        card_brand_users  has_coupon  birthday_year  birthday_month   age  \
# 18099               NaN           0            NaN             NaN   NaN
# 53242              Visa           0            NaN             NaN   NaN
# 39352  American Express           0         1992.0             5.0  27.0
#
#        region  user_id  zone_id  discount due_dates_only  \
# 18099     7.0    38396     74.0       0.0     2017-09-21
# 53242    10.0    14456     74.0       0.0     2016-06-16
# 39352    23.0    15723     61.0       0.0     2017-08-14
#
#                                             card_details  \
# 18099                                                NaN
# 53242  ---\n16/6:\n  :name: '16/6 | 12:00pm | 8 Farre...
# 39352                                                NaN
#
#       card_brand_delivery_info      source  delivery_fee meal_wave  \
# 18099                      NaN       sales         214.0    second
# 53242                     Visa           0         950.0    second
# 39352                     Visa  mobile-ios         500.0     third
#
#        surcharge_amount  promo_code_used  gave_feedback  delivery_order_id  \
# 18099               0.0                0              0             101264
# 53242               0.0                0              0              55798
# 39352               0.0                0              0              97750
#
#        item_id item_type  quantity  unit_price  \
# 18099    461.0      main       3.0      1070.0
# 53242    313.0      main       2.0      1195.0
# 39352    445.0      side       1.0       595.0
#
#                                                     name  \
# 18099              Grilled Garlic and Lime‑leaf Chicken
# 53242  Herb and Lemon Chicken with Oriental Mixed Gra...
# 39352                          Grilled Piri‑Piri Chicken
#
#                                                   macros  \
# 18099  Calories:  577, Fat: 17g, Carb: 64g, Protein: 58g
# 53242   Calories: 530, Fat: 16g, Carb: 48g, Protein: 49g
# 39352    Calories: 210, Fat: 4g, Carb: 4g, Protein: 33g
#
#                                              ingredients temperature category
# 18099  chicken thigh, white rice, sambal paste, ikan ...        warm  regular
# 53242  chicken breast, quinoa, red capsicum, corn, bl...     chilled     main
# 39352  chicken breast, honey cherry tomato, red capsi...     chilled     side

# %%
ini_rows = df.shape[0]
ini_columns=df.shape[1]
print('We have {} records of transactions from {} unique users.'.format(ini_rows,df.user_id.nunique()))
# Out:
# We have 57283 records of transactions from 8886 unique users.

# %%
df['due_dates_only'] = pd.to_datetime(df.due_dates_only)

# %%
df.due_dates_only.dt.year.value_counts()
# Out:
# 2017    36122
# 2015     7796
# 2016     6002
# 2018     5893
# 2014      794
# 2019      676
# Name: due_dates_only, dtype: int64

# %%
#Only take transactions from year 2017 to 2019
df = df[df.due_dates_only.dt.year > 2016]

# %% [markdown]
# ### Group buyer

# %%
plt.figure(figsize=(15,5))
df.groupby('user_id').mean()['quantity'].hist()
plt.show()

# %%
unique_user = df.user_id.unique().tolist()

# %%
#Create new feature where average quantity > 1.5 is a user who makes group purchase
df['groupbuyer'] = 0
for user in tqdm(unique_user):
    if df.groupby('user_id')['quantity'].mean().loc[user] <= 1.5:
        df.loc[df.user_id == user, 'groupbuyer'] = 0
    else:
        df.loc[df.user_id == user, 'groupbuyer'] = 1
# Out:
# HBox(children=(IntProgress(value=0, max=6581), HTML(value='')))

# %%
df.groupbuyer.value_counts()
# Out:
# 0    28179
# 1    14512
# Name: groupbuyer, dtype: int64

# %%
df = df[df.groupbuyer == 0]

# %%
print('We have {} records of transactions from {} unique users.'.format(df.shape[0],df.user_id.nunique()))
# Out:
# We have 28179 records of transactions from 4884 unique users.

# %%
#Find pct of missing values in each column
missing_pct = pd.DataFrame(df.isnull().sum()/df.shape[0], columns=['%Null']).sort_values('%Null',ascending=False)

#Print only those with missing values
missing_pct[missing_pct['%Null']> 0]
# Out:
#                              %Null
# birthday_year             0.810391
# age                       0.810391
# birthday_month            0.807055
# card_details              0.718975
# card_brand_delivery_info  0.181199
# card_brand_users          0.039781
# ingredients               0.000035

# %% [markdown]
# ## Computing Missing values

# %% [markdown]
# ### Ingredients

# %%
#Inspect unique item names for rows with missing values
df[df.ingredients.isnull()]['name'].value_counts()
# Out:
# Beef Goulash with Polenta Cake    1
# Name: name, dtype: int64

# %%
#Compile ingredients as corpus
texts = pd.DataFrame(df[df.ingredients.notnull()].ingredients)

# %%
#Inspect corpus
texts.head()
# Out:
#                                           ingredients
# 3   salmon, couscous, eggplant, zucchini, onion, c...
# 4   salmon, couscous, eggplant, zucchini, onion, c...
# 5   salmon, couscous, eggplant, zucchini, onion, c...
# 8   salmon, couscous, eggplant, zucchini, onion, c...
# 11  salmon, couscous, eggplant, zucchini, onion, c...

# %%
#Remove convert to lowercase and remove punctuations
texts['clean_text'] = texts.ingredients.map(lambda x : ''.join(k.lower() for k in str(x) if k not in string.punctuation))

# %%
#Vectorise the corpus
cvec = CountVectorizer(stop_words='english')
cvec.fit(texts.clean_text)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
print('# of features: {}'.format(len(cvec.get_feature_names())))
# Out:
# # of features: 512

# %%
#Find most common ingredients
bow = pd.DataFrame(cvec.transform(texts.clean_text).todense(),columns=cvec.get_feature_names())
word_count = bow.sum(axis=0)

print("Most common ingredients:")
word_count.sort_values(ascending = False).head(20)
# Out:
# Most common ingredients:
# oil         25804
# rice        22604
# salt        19066
# juice       17605
# sauce       14825
# black       14649
# tomato      14514
# sugar       14151
# chicken     14067
# white       13622
# garlic      13586
# olive       13464
# brown       12121
# onion       11687
# lime        11372
# vinegar     11128
# cherry      10533
# chilli      10061
# red          9322
# mushroom     8975
# dtype: int64

# %% [markdown]
# We will not use this column for modelling as yet.

# %%
#Check possible values
df.category.value_counts()
# Out:
# regular        15962
# highlight       5630
# side            2886
# drink           1779
# dessert         1229
# favorite         263
# guilt-free       217
# local            173
# Main Course       22
# Dessert            5
# Appetiser          5
# off_menu           4
# main               3
# fresh              1
# Name: category, dtype: int64

# %% [markdown]
# There are repeated categories such as 'main' and 'Main Course' which can be consolidated.

# %%
#Consolidating similiar categories
def consolidate_cat(x):
    if x == 'Main Course':
        return 'main'
    elif x == 'Appetiser':
        return 'side'
    elif x == 'Dessert':
        return 'dessert'
    else:
        return x

df.category = df.category.apply(lambda x : consolidate_cat(x))

#Print new categories
df.category.value_counts()
# Out:
# regular       15962
# highlight      5630
# side           2891
# drink          1779
# dessert        1234
# favorite        263
# guilt-free      217
# local           173
# main             25
# off_menu          4
# fresh             1
# Name: category, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Macros

# %% [markdown]
# Split out macros into components: Calories, Fat, Protein, Carbs

# %%
#Inspect macros
df.macros.head()
# Out:
# 3     Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 4     Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 5     Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 8     Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# 11    Calories: 442, Fat: 12g, Carb: 42g, Protein: 44g
# Name: macros, dtype: object

# %%
new = df.macros.str.split(',', n=5, expand=True)

# %%
def split_values_into_name_and_val(col):
    new[str(col)+'_macros_name'] = new[col].str.split(': ', n=2, expand=True)[0].fillna('None').map(lambda x: x.lower())
    new[str(col)+'_macros_val'] = new[col].str.split(': ', n=2, expand=True)[1]
    print(new[str(col)+'_macros_name'].unique())

for col in new:
    split_values_into_name_and_val(col)

new.head()
# Out:
# ['calories' 'serving size' 'coming soon']
# [' fat' ' protein' ' calories' 'none' ' carbs']
# [' carb' ' fat' 'none' ' protein']
# [' protein' ' carb' 'none' '  fat']
# ['none' ' protein']
#                 0          1           2              3     4 0_macros_name  \
# 3   Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 4   Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 5   Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 8   Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
# 11  Calories: 442   Fat: 12g   Carb: 42g   Protein: 44g  None      calories
#
#    0_macros_val 1_macros_name 1_macros_val 2_macros_name 2_macros_val  \
# 3           442           fat          12g          carb          42g
# 4           442           fat          12g          carb          42g
# 5           442           fat          12g          carb          42g
# 8           442           fat          12g          carb          42g
# 11          442           fat          12g          carb          42g
#
#    3_macros_name 3_macros_val 4_macros_name 4_macros_val
# 3        protein          44g          none         None
# 4        protein          44g          none         None
# 5        protein          44g          none         None
# 8        protein          44g          none         None
# 11       protein          44g          none         None

# %%
new.shape
# Out:
# (28179, 15)

# %%
new['calories'] = 0
new['fat'] = 0
new['protein'] = 0
new['carb'] = 0

# %%
new.loc[new['0_macros_name'] == 'calories', 'calories'] = new.loc[new['0_macros_name'] == 'calories', '0_macros_val']
# new.loc[new['0_macros_name'] == ' calories', 'calories'] = new.loc[new['0_macros_name'] == ' calories', '0_macros_val']

new.loc[new['1_macros_name'] == ' calories', 'calories'] = new.loc[new['1_macros_name'] == ' calories', '1_macros_val']
new.loc[new['1_macros_name'] == ' fat', 'fat'] = new.loc[new['1_macros_name'] == ' fat', '1_macros_val']
new.loc[new['1_macros_name'] == ' protein', 'protein'] = new.loc[new['1_macros_name'] == ' protein', '1_macros_val']
new.loc[new['1_macros_name'] == ' carbs', 'carb'] = new.loc[new['1_macros_name'] == ' carbs', '1_macros_val']

new.loc[new['2_macros_name'] == ' fat', 'fat'] = new.loc[new['2_macros_name'] == ' fat', '2_macros_val']
new.loc[new['2_macros_name'] == ' protein', 'protein'] = new.loc[new['2_macros_name'] == ' protein', '2_macros_val']
new.loc[new['2_macros_name'] == ' carb', 'carb'] = new.loc[new['2_macros_name'] == ' carb', '2_macros_val']

new.loc[new['3_macros_name'] == '  fat', 'fat'] = new.loc[new['3_macros_name'] == '  fat', '3_macros_val']
new.loc[new['3_macros_name'] == ' protein', 'protein'] = new.loc[new['3_macros_name'] == ' protein', '3_macros_val']
new.loc[new['3_macros_name'] == ' carb', 'carb'] = new.loc[new['3_macros_name'] == ' carb', '3_macros_val']

new.loc[new['4_macros_name'] == ' protein', 'protein'] = new.loc[new['4_macros_name'] == ' protein', '4_macros_val']

# %%
#Remove g
cols = ['fat','protein','carb']
for i in cols:
    new[str(i)] = new[str(i)].apply(lambda x: str(x).split('g')[0])

# %%
df = pd.concat([df, new[['calories','fat','protein','carb']]],axis=1)

for i in ['calories', 'fat','protein','carb']:
    df[i] = df[i].astype(float)

# %% [markdown]
# ### Account Balance

# %%
df.account_balance.dtype
# Out:
# dtype('int64')

# %%
df['use_wallet'] = df.account_balance.map(lambda x: 1 if x != 0 else 0)

# %%
df.use_wallet.value_counts()
# Out:
# 0    25091
# 1     3088
# Name: use_wallet, dtype: int64

# %% [markdown]
# ### Meal wave

# %%
df.meal_wave.value_counts()
# Out:
# first     11716
# second    10973
# third      4762
# 0           728
# Name: meal_wave, dtype: int64

# %%
df_mw = pd.get_dummies(df.meal_wave, drop_first=True)

# %% [markdown]
# ### Calorie, Fat, Protein, Carb preference

# %%
cal = df.groupby('item_id')['calories'].mean()
plt.figure(figsize=(15,5))
sns.distplot(cal, bins=40)
plt.xticks(np.arange(min(cal), max(cal)+1, 50))
plt.show()

# %%
#Low calorie == ≤100g (≤ 40 kilocalorie per 100g for 1 serving 250g)
def calorie_pref(x):
    if x <= 100 :
        return 1 #preference for low calorie
    else:
        return 0 

df['calorie_pref'] = df.calories.map(lambda x : calorie_pref(x))

# %%
fat = df.groupby('item_id')['fat'].mean()
plt.figure(figsize=(15,5))
sns.distplot(fat, bins=40)
plt.xticks(np.arange(min(fat), max(fat)+1, 5))
plt.show()

# %%
#Low fat == ≤7.5g (≤3g fat per 100g for 1 serving 250g) 
def fat_pref(x):
    if x <= 7.5 :
        return 1 #preference for low fat
    else:
        return 0  
    
df['fat_pref'] = df.fat.map(lambda x : fat_pref(x))

# %%
pro = df.groupby('item_id')['protein'].mean()
plt.figure(figsize=(15,5))
sns.distplot(pro, bins=40)
plt.xticks(np.arange(min(pro), max(pro)+1, 5))
plt.show()

# %%
#Rich in protein == ≥25 (≥10g of protein per 100g for 1 serving 250g)
def pro_pref(x):
    if x >= 25 :
        return 1 #preference for high protein
    else:
        return 0  
    
df['pro_pref'] = df.protein.map(lambda x : pro_pref(x))

# %%
carbs = df.groupby('item_id')['carb'].mean()
plt.figure(figsize=(15,5))
sns.distplot(carbs, bins=40)
plt.xticks(np.arange(min(carbs), max(carbs)+1, 5))
plt.show()

# %%
#Low carbs == ≤25 (≤10 g carbohydrate per 100g for 1 serving 250g)
def carb_pref(x):
    if x <= 25 :
        return 1 #preference for low carb
    else:
        return 0  
    
df['carb_pref'] = df.carb.map(lambda x : carb_pref(x))

# %%
df[['calorie_pref','pro_pref','fat_pref','carb_pref']].isnull().sum()
# Out:
# calorie_pref    0
# pro_pref        0
# fat_pref        0
# carb_pref       0
# dtype: int64

# %%
df.groupby('user_id').sum()['quantity'].sort_values(ascending=False).head()
# Out:
# user_id
# 26810    324.0
# 31940    307.0
# 17491    165.0
# 35009    153.0
# 14775    151.0
# Name: quantity, dtype: float64

# %% [markdown]
# Find preferences of the user for which we have the most data points. We will normalise this later.

# %%
norm = pd.DataFrame(df[df.user_id == 26810][['calorie_pref', 'fat_pref','pro_pref', 'carb_pref']].mean())
norm
# Out:
#                      0
# calorie_pref  0.135593
# fat_pref      0.233051
# pro_pref      0.677966
# carb_pref     0.186441

# %% [markdown]
# ### Temperature

# %%
df.temperature.value_counts()
# Out:
# warm       18970
# chilled     9209
# Name: temperature, dtype: int64

# %%
df['is_chilled'] = df.temperature.map(lambda x : 1 if x == 'chilled' else 0)

# %% [markdown]
# ### Category

# %%
df.category.value_counts()
# Out:
# regular       15962
# highlight      5630
# side           2891
# drink          1779
# dessert        1234
# favorite        263
# guilt-free      217
# local           173
# main             25
# off_menu          4
# fresh             1
# Name: category, dtype: int64

# %%
df_cat = pd.get_dummies(df.category, drop_first=True) #drop dessert
df_cat.columns
# Out:
# Index(['drink', 'favorite', 'fresh', 'guilt-free', 'highlight', 'local',
#        'main', 'off_menu', 'regular', 'side'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df_cat.corr(), annot=True, cmap='RdBu_r')
plt.show()

# %% [markdown]
# ## Modelling

# %%
df_merge_mean = pd.concat([df,df_cat,df_mw], axis=1).groupby('user_id').mean()

# %%
df_merge_mean.sample(5)
# Out:
#          postal_code  account_balance  has_coupon  birthday_year  \
# user_id
# 45397       758057.0            500.0         0.0            NaN
# 6908         68895.0              0.0         1.0            NaN
# 35107       419713.0              0.0         0.0            NaN
# 19890       637488.0              0.0         0.0         1989.0
# 36530       249488.0              0.0         1.0            NaN
#
#          birthday_month   age  region  zone_id  discount  delivery_fee  \
# user_id
# 45397               NaN   NaN    27.0     61.0       0.0    500.000000
# 6908                NaN   NaN     1.0     74.0       0.0      0.000000
# 35107               NaN   NaN    14.0     71.0     500.0    200.000000
# 19890               6.0  30.0    22.0     74.0       0.0     57.142857
# 36530               NaN   NaN    10.0     74.0       0.0    200.000000
#
#          surcharge_amount  promo_code_used  gave_feedback  delivery_order_id  \
# user_id
# 45397               450.0              0.0       0.000000      126263.000000
# 6908                  0.0              0.0       0.666667       94441.000000
# 35107               300.0              1.0       0.000000       93238.000000
# 19890                 0.0              0.0       0.714286       90261.285714
# 36530               300.0              0.0       0.000000       95986.000000
#
#             item_id  quantity   unit_price  groupbuyer    calories        fat  \
# user_id
# 45397    539.000000  0.000000  1595.000000         0.0  587.000000  34.000000
# 6908     369.666667  1.000000  1028.333333         0.0  427.000000  13.333333
# 35107    336.000000  1.000000  1195.000000         0.0  549.000000  14.000000
# 19890    392.285714  1.428571  1060.000000         0.0  464.142857  12.142857
# 36530    336.000000  1.000000  1195.000000         0.0  549.000000  14.000000
#
#            protein       carb  use_wallet  calorie_pref  fat_pref  pro_pref  \
# user_id
# 45397    37.000000  37.000000         1.0      0.000000  0.000000  1.000000
# 6908     37.666667  53.000000         0.0      0.000000  0.333333  1.000000
# 35107    45.000000  61.000000         0.0      0.000000  0.000000  1.000000
# 19890    31.428571  64.428571         0.0      0.142857  0.285714  0.571429
# 36530    45.000000  61.000000         0.0      0.000000  0.000000  1.000000
#
#          carb_pref  is_chilled  drink  favorite  fresh  guilt-free  highlight  \
# user_id
# 45397     0.000000    0.000000    0.0  0.000000    0.0         0.0   1.000000
# 6908      0.333333    0.666667    0.0  0.000000    0.0         0.0   0.333333
# 35107     0.000000    0.000000    0.0  0.000000    0.0         0.0   0.000000
# 19890     0.142857    0.428571    0.0  0.142857    0.0         0.0   0.000000
# 36530     0.000000    0.000000    0.0  0.000000    0.0         0.0   0.000000
#
#          local  main  off_menu   regular      side     first    second  third
# user_id
# 45397      0.0   0.0       0.0  0.000000  0.000000  1.000000  0.000000    0.0
# 6908       0.0   0.0       0.0  0.333333  0.333333  0.000000  1.000000    0.0
# 35107      0.0   0.0       0.0  1.000000  0.000000  0.000000  1.000000    0.0
# 19890      0.0   0.0       0.0  0.714286  0.142857  0.285714  0.714286    0.0
# 36530      0.0   0.0       0.0  1.000000  0.000000  1.000000  0.000000    0.0

# %%
df_merge_mean['calorie_pref_norm'] = df_merge_mean.calorie_pref/norm[0][0]
df_merge_mean['fat_pref_norm'] = df_merge_mean.fat_pref/norm[0][1]
df_merge_mean['pro_pref_norm'] = df_merge_mean.pro_pref/norm[0][2]
df_merge_mean['carb_pref_norm'] = df_merge_mean.carb_pref/norm[0][3]
df_merge_mean['is_chilled_norm'] = df_merge_mean.is_chilled/df[df.user_id == 26810][['is_chilled']].mean()[0]

# %%
df_merge_mean.columns
# Out:
# Index(['postal_code', 'account_balance', 'has_coupon', 'birthday_year',
#        'birthday_month', 'age', 'region', 'zone_id', 'discount',
#        'delivery_fee', 'surcharge_amount', 'promo_code_used', 'gave_feedback',
#        'delivery_order_id', 'item_id', 'quantity', 'unit_price', 'groupbuyer',
#        'calories', 'fat', 'protein', 'carb', 'use_wallet', 'calorie_pref',
#        'fat_pref', 'pro_pref', 'carb_pref', 'is_chilled', 'drink', 'favorite',
#        'fresh', 'guilt-free', 'highlight', 'local', 'main', 'off_menu',
#        'regular', 'side', 'first', 'second', 'third', 'calorie_pref_norm',
#        'fat_pref_norm', 'pro_pref_norm', 'carb_pref_norm', 'is_chilled_norm'],
#       dtype='object')

# %%
features = ['region','use_wallet','has_coupon',
            'first', 'second','third','delivery_fee',
            'gave_feedback','unit_price', 'drink',
            'favorite', 'fresh', 'guilt-free', 'highlight', 
            'local', 'main','off_menu', 'regular', 
            'side','calorie_pref_norm', 'fat_pref_norm','pro_pref_norm', 
            'carb_pref_norm','is_chilled_norm'
           ]

# %%
X = df_merge_mean[features].round(2)

# %%
X.sample(5)
# Out:
#          region  use_wallet  has_coupon  first  second  third  delivery_fee  \
# user_id
# 48996      25.0         0.0         0.0    1.0    0.00   0.00        500.00
# 33201      17.0         0.0         0.0    0.0    1.00   0.00        200.00
# 31149      20.0         0.0         0.0    1.0    0.00   0.00        650.00
# 29981      22.0         0.0         0.0    0.0    0.71   0.29        228.57
# 30282      10.0         0.0         0.0    1.0    0.00   0.00        300.00
#
#          gave_feedback  unit_price  drink  favorite  fresh  guilt-free  \
# user_id
# 48996             0.00     1022.50   0.50      0.00    0.0         0.0
# 33201             1.00     1202.50   0.00      0.00    0.0         0.0
# 31149             1.00     1128.33   0.00      0.33    0.0         0.0
# 29981             0.43     1250.00   0.00      0.00    0.0         0.0
# 30282             1.00      795.00   0.67      0.00    0.0         0.0
#
#          highlight  local  main  off_menu  regular  side  calorie_pref_norm  \
# user_id
# 48996         0.25    0.0   0.0       0.0     0.25  0.00               3.69
# 33201         0.00    0.0   0.0       0.0     1.00  0.00               0.00
# 31149         0.00    0.0   0.0       0.0     0.33  0.33               0.00
# 29981         0.29    0.0   0.0       0.0     0.57  0.14               0.00
# 30282         0.00    0.0   0.0       0.0     0.33  0.00               4.92
#
#          fat_pref_norm  pro_pref_norm  carb_pref_norm  is_chilled_norm
# user_id
# 48996             2.15           0.74            2.68             2.53
# 33201             0.00           1.48            0.00             1.69
# 31149             0.00           0.98            1.79             1.12
# 29981             0.61           1.26            0.00             1.44
# 30282             2.86           0.49            3.58             2.25

# %%
plt.figure(figsize=(15,7))
sns.heatmap(X.corr(), annot=True, cmap='RdBu_r')
plt.show()

# %%
ss = StandardScaler()
Xs = ss.fit_transform(X)

# %% [markdown]
# ### PCA

# %%
pca = PCA()
principalComponents = pca.fit_transform(Xs)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_)
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)

# Save components to a DataFrame
PCA_components = pd.DataFrame(principalComponents)

# %% [markdown]
# ### KMeans

# %%
ks = range(1, 10)
inertias = []
silhouette_scores = []
for k in ks:
    # Create a KMeans instance with k clusters: model
    knn_model = KMeans(n_clusters=k)
    
    # Fit model to samples
    knn_model.fit(PCA_components.iloc[:,:3])
    
    # Append the inertia to the list of inertias
    inertias.append(knn_model.inertia_)

    
plt.plot(ks, inertias, '-o', color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
plt.scatter(PCA_components[0], PCA_components[1], alpha=.1, color='black')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
# Out:
# Text(0, 0.5, 'PCA 2')

# %%
model = KMeans(n_clusters=2)
model.fit(PCA_components.iloc[:,:2])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
pred = model.labels_

# %%
# Users and clusters
# pd.DataFrame({'Users': X.index, 'Cluster': pred})

# %%
df_merge_mean['cluster'] = pred

# %%
df_merge_mean.cluster.value_counts()
# Out:
# 1    3938
# 0     946
# Name: cluster, dtype: int64

# %%
silhouette_score(Xs, pred, metric='euclidean')
# Out:
# 0.2355592421762232

# %% [markdown]
# ### Interpretation

# %%
X.columns
# Out:
# Index(['region', 'use_wallet', 'has_coupon', 'first', 'second', 'third',
#        'delivery_fee', 'gave_feedback', 'unit_price', 'drink', 'favorite',
#        'fresh', 'guilt-free', 'highlight', 'local', 'main', 'off_menu',
#        'regular', 'side', 'calorie_pref_norm', 'fat_pref_norm',
#        'pro_pref_norm', 'carb_pref_norm', 'is_chilled_norm'],
#       dtype='object')

# %%
df_merge_mean[df_merge_mean.cluster == 1]['first'].median()
# Out:
# 0.0

# %%
df_merge_mean[df_merge_mean.cluster == 0]['first'].median()
# Out:
# 0.15192307692307694

# %%
df_merge_mean[df_merge_mean.cluster == 1]['unit_price'].median()
# Out:
# 1195.0

# %%
df_merge_mean[df_merge_mean.cluster == 0]['unit_price'].median()
# Out:
# 958.3403361344538

# %%
df_merge_mean[df_merge_mean.cluster == 1]['calorie_pref'].median()
# Out:
# 0.0

# %%
df_merge_mean[df_merge_mean.cluster == 0]['calorie_pref'].median()
# Out:
# 0.3333333333333333

# %%
df_merge_mean[df_merge_mean.cluster == 1]['fat_pref'].median()
# Out:
# 0.0

# %%
df_merge_mean[df_merge_mean.cluster == 0]['fat_pref'].median()
# Out:
# 0.5

# %%
df_merge_mean[df_merge_mean.cluster == 1]['is_chilled'].median()
# Out:
# 0.0

# %%
df_merge_mean[df_merge_mean.cluster == 0]['is_chilled'].median()
# Out:
# 0.5
